# %% [markdown]
# <a href="https://colab.research.google.com/github/sauravsingla/Outlier_Detection_Tutorials/blob/master/Tutorial_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Autoencoders

# %%
# import packages
import pandas as pd
import numpy as np
from scipy import stats
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import StandardScaler
from pylab import rcParams
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

#random seed and test data %
RANDOM_SEED = 314 
TEST_PCT = 0.2 

#graphic style 
rcParams['figure.figsize'] = 14, 8.7 
LABELS = ["Normal","Fraud"]
col_list = ["cerulean","scarlet"]
sns.set(style='white', font_scale=1.75, palette=sns.xkcd_palette(col_list))
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv("/creditcard.csv") 
df.head(n=5)
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().values.any()
# Out:
# False

# %%
pd.value_counts(df['Class'], sort = True) #class count 0=Normal 1=Fraud
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#imbalanced two classes 
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.xticks(range(2), LABELS)
plt.title("Frequency by observation number")
plt.xlabel("Class")
plt.ylabel("Number of Observations");

# %%
normal_df = df[df.Class == 0] #normal_df 
fraud_df = df[df.Class == 1] #fraud_df

# %%
normal_df.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud_df.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#Visualise high value transactions
bins = np.linspace(200, 2500, 100)
plt.hist(normal_df.Amount, bins, alpha=1,  label='Normal')
plt.hist(fraud_df.Amount, bins, alpha=0.6,  label='Fraud')
plt.legend(loc='upper right')
plt.title("Amount by percentage of transactions (transactions \$200+)")
plt.xlabel("Transaction amount (USD)")
plt.ylabel("Percentage of transactions (%)");
plt.show()

# %%
bins = np.linspace(0, 48, 48) #48 hours
plt.hist((normal_df.Time/(60*60)), bins, alpha=1,  label='Normal')
plt.hist((fraud_df.Time/(60*60)), bins, alpha=0.6,  label='Fraud')
plt.legend(loc='upper right')
plt.title("% of transactions by hour")
plt.xlabel("Transaction time as measured from first transaction (hours)")
plt.ylabel("% of transactions ");
plt.show()

# %%
plt.scatter((normal_df.Time/(60*60)), normal_df.Amount, alpha=0.6, label='Normal')
plt.scatter((fraud_df.Time/(60*60)), fraud_df.Amount, alpha=0.9, label='Fraud')
plt.title("Amount of transaction by hour")
plt.xlabel("Transaction time as measured from first transaction (hours)")
plt.ylabel('Amount in (USD)')
plt.legend(loc='upper right')
plt.show()

# %%
df_norm = df
df_norm['Time'] = StandardScaler().fit_transform(df_norm['Time'].values.reshape(-1, 1))
df_norm['Amount'] = StandardScaler().fit_transform(df_norm['Amount'].values.reshape(-1, 1))

# %%
train_x, test_x = train_test_split(df_norm, test_size=TEST_PCT, random_state=RANDOM_SEED)
train_x = train_x[train_x.Class == 0] #where normal transactions
train_x = train_x.drop(['Class'], axis=1) #drop the class column


test_y = test_x['Class'] #save the class column for the test set
test_x = test_x.drop(['Class'], axis=1) #drop the class column

train_x = train_x.values #transform to ndarray
test_x = test_x.values

# %%
train_x.shape
# Out:
# (227468, 30)

# %%
nb_epoch = 100
batch_size = 128
input_dim = train_x.shape[1] #num of columns, 30
encoding_dim = 14
hidden_dim = int(encoding_dim / 2) #example 7
learning_rate = 1e-7

input_layer = Input(shape=(input_dim, ))
encoder = Dense(encoding_dim, activation="tanh", activity_regularizer=regularizers.l1(learning_rate))(input_layer)
encoder = Dense(hidden_dim, activation="relu")(encoder)
decoder = Dense(hidden_dim, activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
autoencoder.compile(metrics=['accuracy'],
                    loss='mean_squared_error',
                    optimizer='adam')

cp = ModelCheckpoint(filepath="autoencoder_fraud.h5",
                               save_best_only=True,
                               verbose=0)

tb = TensorBoard(log_dir='./logs',
                histogram_freq=0,
                write_graph=True,
                write_images=True)

history = autoencoder.fit(train_x, train_x,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(test_x, test_x),
                    verbose=1,
                    callbacks=[cp, tb]).history
# Out:
# Epoch 1/100
#    1/1778 [..............................] - ETA: 0s - loss: 0.9010 - accuracy: 0.0156WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0099s vs `on_train_batch_end` time: 0.0288s). Check your callbacks.
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.8503 - accuracy: 0.4882 - val_loss: 0.8114 - val_accuracy: 0.5964
# Epoch 2/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7570 - accuracy: 0.6270 - val_loss: 0.7757 - val_accuracy: 0.6413
# Epoch 3/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7353 - accuracy: 0.6571 - val_loss: 0.7629 - val_accuracy: 0.6707
# Epoch 4/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7270 - accuracy: 0.6735 - val_loss: 0.7578 - val_accuracy: 0.6774
# Epoch 5/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7225 - accuracy: 0.6782 - val_loss: 0.7541 - val_accuracy: 0.6755
# Epoch 6/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7194 - accuracy: 0.6780 - val_loss: 0.7510 - val_accuracy: 0.6756
# Epoch 7/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7162 - accuracy: 0.6814 - val_loss: 0.7469 - val_accuracy: 0.6812
# Epoch 8/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7132 - accuracy: 0.6876 - val_loss: 0.7445 - val_accuracy: 0.6900
# Epoch 9/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7107 - accuracy: 0.6936 - val_loss: 0.7425 - val_accuracy: 0.6964
# Epoch 10/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7090 - accuracy: 0.6962 - val_loss: 0.7412 - val_accuracy: 0.6983
# Epoch 11/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7078 - accuracy: 0.6989 - val_loss: 0.7399 - val_accuracy: 0.7013
# Epoch 12/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7072 - accuracy: 0.7002 - val_loss: 0.7393 - val_accuracy: 0.7024
# Epoch 13/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7058 - accuracy: 0.7017 - val_loss: 0.7386 - val_accuracy: 0.7004
# Epoch 14/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7051 - accuracy: 0.7016 - val_loss: 0.7392 - val_accuracy: 0.6913
# Epoch 15/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7045 - accuracy: 0.7016 - val_loss: 0.7375 - val_accuracy: 0.7037
# Epoch 16/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7038 - accuracy: 0.7030 - val_loss: 0.7366 - val_accuracy: 0.7026
# Epoch 17/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7033 - accuracy: 0.7032 - val_loss: 0.7360 - val_accuracy: 0.7072
# Epoch 18/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.7029 - accuracy: 0.7044 - val_loss: 0.7354 - val_accuracy: 0.7056
# Epoch 19/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7022 - accuracy: 0.7045 - val_loss: 0.7354 - val_accuracy: 0.7020
# Epoch 20/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7017 - accuracy: 0.7049 - val_loss: 0.7355 - val_accuracy: 0.7042
# Epoch 21/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7019 - accuracy: 0.7049 - val_loss: 0.7360 - val_accuracy: 0.7018
# Epoch 22/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7013 - accuracy: 0.7054 - val_loss: 0.7340 - val_accuracy: 0.7059
# Epoch 23/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7011 - accuracy: 0.7051 - val_loss: 0.7340 - val_accuracy: 0.7080
# Epoch 24/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7006 - accuracy: 0.7055 - val_loss: 0.7345 - val_accuracy: 0.7068
# Epoch 25/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7009 - accuracy: 0.7052 - val_loss: 0.7338 - val_accuracy: 0.7066
# Epoch 26/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7005 - accuracy: 0.7056 - val_loss: 0.7332 - val_accuracy: 0.7066
# Epoch 27/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7001 - accuracy: 0.7058 - val_loss: 0.7352 - val_accuracy: 0.7027
# Epoch 28/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7000 - accuracy: 0.7052 - val_loss: 0.7340 - val_accuracy: 0.6993
# Epoch 29/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.7001 - accuracy: 0.7058 - val_loss: 0.7332 - val_accuracy: 0.7071
# Epoch 30/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6999 - accuracy: 0.7062 - val_loss: 0.7330 - val_accuracy: 0.7048
# Epoch 31/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6994 - accuracy: 0.7060 - val_loss: 0.7336 - val_accuracy: 0.7024
# Epoch 32/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6993 - accuracy: 0.7059 - val_loss: 0.7324 - val_accuracy: 0.7072
# Epoch 33/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6993 - accuracy: 0.7052 - val_loss: 0.7329 - val_accuracy: 0.7075
# Epoch 34/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6991 - accuracy: 0.7062 - val_loss: 0.7334 - val_accuracy: 0.7072
# Epoch 35/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6988 - accuracy: 0.7063 - val_loss: 0.7336 - val_accuracy: 0.7011
# Epoch 36/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6990 - accuracy: 0.7054 - val_loss: 0.7313 - val_accuracy: 0.7068
# Epoch 37/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6987 - accuracy: 0.7054 - val_loss: 0.7320 - val_accuracy: 0.7063
# Epoch 38/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6988 - accuracy: 0.7050 - val_loss: 0.7315 - val_accuracy: 0.7030
# Epoch 39/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6984 - accuracy: 0.7045 - val_loss: 0.7327 - val_accuracy: 0.7038
# Epoch 40/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6983 - accuracy: 0.7046 - val_loss: 0.7330 - val_accuracy: 0.7060
# Epoch 41/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6982 - accuracy: 0.7049 - val_loss: 0.7316 - val_accuracy: 0.7065
# Epoch 42/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6978 - accuracy: 0.7037 - val_loss: 0.7308 - val_accuracy: 0.7050
# Epoch 43/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6980 - accuracy: 0.7045 - val_loss: 0.7309 - val_accuracy: 0.7027
# Epoch 44/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6978 - accuracy: 0.7048 - val_loss: 0.7305 - val_accuracy: 0.7100
# Epoch 45/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6977 - accuracy: 0.7052 - val_loss: 0.7311 - val_accuracy: 0.7056
# Epoch 46/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6977 - accuracy: 0.7052 - val_loss: 0.7303 - val_accuracy: 0.7077
# Epoch 47/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6976 - accuracy: 0.7050 - val_loss: 0.7300 - val_accuracy: 0.7074
# Epoch 48/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6973 - accuracy: 0.7059 - val_loss: 0.7304 - val_accuracy: 0.7033
# Epoch 49/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6972 - accuracy: 0.7066 - val_loss: 0.7304 - val_accuracy: 0.7106
# Epoch 50/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6973 - accuracy: 0.7076 - val_loss: 0.7302 - val_accuracy: 0.7065
# Epoch 51/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6973 - accuracy: 0.7080 - val_loss: 0.7304 - val_accuracy: 0.7140
# Epoch 52/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6970 - accuracy: 0.7088 - val_loss: 0.7308 - val_accuracy: 0.7046
# Epoch 53/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6965 - accuracy: 0.7089 - val_loss: 0.7310 - val_accuracy: 0.7034
# Epoch 54/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6965 - accuracy: 0.7089 - val_loss: 0.7305 - val_accuracy: 0.7060
# Epoch 55/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6965 - accuracy: 0.7092 - val_loss: 0.7305 - val_accuracy: 0.7086
# Epoch 56/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6968 - accuracy: 0.7094 - val_loss: 0.7296 - val_accuracy: 0.7112
# Epoch 57/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6963 - accuracy: 0.7099 - val_loss: 0.7299 - val_accuracy: 0.7085
# Epoch 58/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6964 - accuracy: 0.7098 - val_loss: 0.7293 - val_accuracy: 0.7095
# Epoch 59/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6962 - accuracy: 0.7100 - val_loss: 0.7297 - val_accuracy: 0.7124
# Epoch 60/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6968 - accuracy: 0.7109 - val_loss: 0.7294 - val_accuracy: 0.7129
# Epoch 61/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6961 - accuracy: 0.7112 - val_loss: 0.7298 - val_accuracy: 0.7126
# Epoch 62/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6961 - accuracy: 0.7107 - val_loss: 0.7308 - val_accuracy: 0.7008
# Epoch 63/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6961 - accuracy: 0.7103 - val_loss: 0.7292 - val_accuracy: 0.7096
# Epoch 64/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6958 - accuracy: 0.7113 - val_loss: 0.7304 - val_accuracy: 0.7112
# Epoch 65/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6964 - accuracy: 0.7104 - val_loss: 0.7293 - val_accuracy: 0.7161
# Epoch 66/100
# 1778/1778 [==============================] - 3s 1ms/step - loss: 0.6955 - accuracy: 0.7118 - val_loss: 0.7308 - val_accuracy: 0.7144
# Epoch 67/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6957 - accuracy: 0.7111 - val_loss: 0.7289 - val_accuracy: 0.7103
# Epoch 68/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6960 - accuracy: 0.7110 - val_loss: 0.7290 - val_accuracy: 0.7097
# Epoch 69/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6956 - accuracy: 0.7116 - val_loss: 0.7297 - val_accuracy: 0.7026
# Epoch 70/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6957 - accuracy: 0.7114 - val_loss: 0.7293 - val_accuracy: 0.7152
# Epoch 71/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6956 - accuracy: 0.7120 - val_loss: 0.7297 - val_accuracy: 0.7104
# Epoch 72/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6957 - accuracy: 0.7115 - val_loss: 0.7292 - val_accuracy: 0.7100
# Epoch 73/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6956 - accuracy: 0.7122 - val_loss: 0.7288 - val_accuracy: 0.7129
# Epoch 74/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6957 - accuracy: 0.7115 - val_loss: 0.7291 - val_accuracy: 0.7092
# Epoch 75/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6956 - accuracy: 0.7124 - val_loss: 0.7287 - val_accuracy: 0.7119
# Epoch 76/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6953 - accuracy: 0.7122 - val_loss: 0.7290 - val_accuracy: 0.7104
# Epoch 77/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6951 - accuracy: 0.7123 - val_loss: 0.7288 - val_accuracy: 0.7093
# Epoch 78/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6952 - accuracy: 0.7127 - val_loss: 0.7293 - val_accuracy: 0.7133
# Epoch 79/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6953 - accuracy: 0.7118 - val_loss: 0.7282 - val_accuracy: 0.7167
# Epoch 80/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6955 - accuracy: 0.7127 - val_loss: 0.7290 - val_accuracy: 0.7141
# Epoch 81/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6952 - accuracy: 0.7128 - val_loss: 0.7291 - val_accuracy: 0.7170
# Epoch 82/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6953 - accuracy: 0.7129 - val_loss: 0.7302 - val_accuracy: 0.7115
# Epoch 83/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6950 - accuracy: 0.7125 - val_loss: 0.7293 - val_accuracy: 0.7127
# Epoch 84/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6948 - accuracy: 0.7135 - val_loss: 0.7288 - val_accuracy: 0.7144
# Epoch 85/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6951 - accuracy: 0.7125 - val_loss: 0.7280 - val_accuracy: 0.7138
# Epoch 86/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6949 - accuracy: 0.7127 - val_loss: 0.7303 - val_accuracy: 0.7132
# Epoch 87/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6953 - accuracy: 0.7128 - val_loss: 0.7283 - val_accuracy: 0.7115
# Epoch 88/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6950 - accuracy: 0.7130 - val_loss: 0.7286 - val_accuracy: 0.7083
# Epoch 89/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6947 - accuracy: 0.7137 - val_loss: 0.7281 - val_accuracy: 0.7121
# Epoch 90/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6950 - accuracy: 0.7132 - val_loss: 0.7277 - val_accuracy: 0.7163
# Epoch 91/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6946 - accuracy: 0.7128 - val_loss: 0.7306 - val_accuracy: 0.6985
# Epoch 92/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6950 - accuracy: 0.7131 - val_loss: 0.7277 - val_accuracy: 0.7176
# Epoch 93/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6946 - accuracy: 0.7139 - val_loss: 0.7271 - val_accuracy: 0.7160
# Epoch 94/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6948 - accuracy: 0.7129 - val_loss: 0.7278 - val_accuracy: 0.7163
# Epoch 95/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6946 - accuracy: 0.7142 - val_loss: 0.7280 - val_accuracy: 0.7073
# Epoch 96/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6949 - accuracy: 0.7128 - val_loss: 0.7291 - val_accuracy: 0.7063
# Epoch 97/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6945 - accuracy: 0.7137 - val_loss: 0.7273 - val_accuracy: 0.7158
# Epoch 98/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6948 - accuracy: 0.7134 - val_loss: 0.7293 - val_accuracy: 0.7117
# Epoch 99/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6948 - accuracy: 0.7148 - val_loss: 0.7273 - val_accuracy: 0.7165
# Epoch 100/100
# 1778/1778 [==============================] - 2s 1ms/step - loss: 0.6947 - accuracy: 0.7131 - val_loss: 0.7282 - val_accuracy: 0.7082

# %%
plt.plot(history['loss'], linewidth=2, label='Train')
plt.plot(history['val_loss'], linewidth=2, label='Test')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
test_x_predictions = autoencoder.predict(test_x)
mse = np.mean(np.power(test_x - test_x_predictions, 2), axis=1)
error_df = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': test_y})
error_df.describe()
# Out:
#        Reconstruction_error    True_class
# count          56962.000000  56962.000000
# mean               0.728218      0.002019
# std                3.107271      0.044887
# min                0.054996      0.000000
# 25%                0.251845      0.000000
# 50%                0.395653      0.000000
# 75%                0.628807      0.000000
# max              190.155754      1.000000

# %%
false_pos_rate, true_pos_rate, thresholds = roc_curve(error_df.True_class, error_df.Reconstruction_error)
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth=5, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth=5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
precision_rt, recall_rt, threshold_rt = precision_recall_curve(error_df.True_class, error_df.Reconstruction_error)
plt.plot(recall_rt, precision_rt, linewidth=5, label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(threshold_rt, precision_rt[1:], label="Precision",linewidth=5)
plt.plot(threshold_rt, recall_rt[1:], label="Recall",linewidth=5)
plt.title('Precision and recall for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision/Recall')
plt.legend()
plt.show()

# %%
threshold_fixed = 5
groups = error_df.groupby('True_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold_fixed, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
pred_y = [1 if e > threshold_fixed else 0 for e in error_df.Reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.True_class, pred_y)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
